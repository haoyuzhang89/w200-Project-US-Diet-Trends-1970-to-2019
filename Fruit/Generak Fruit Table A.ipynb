# %%
# Module & Package  - Run here

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.ticker as mtick

# %matplotlib inline
plt.style.use('default')

# %% [markdown]
# ## Table A-1--U.S. per capita use of selected, commercially produced, fresh, and processing fruit and tree nuts, 1976 to date
#
# Unit: Pounds, Farm weight
#
# * Total for all items will not match previous Yearbook issues due to the inclusion of melons. d = discontinued.
# 1 Data may not match other tables due to rounding.  Year reflects end of harvest for citrus and beginning year of harvest for noncitrus. 2 Method for calculating orange
# juice changed in 1987.
# 3 Includes tangerines, tangelos, other mandarins, and limes.
# 4 Includes nectarines.
# 5  Does not include small quantities of dried and other
# processed products.
# 6 Includes apricots, blueberries, cranberries, kiwifruit,  mangoes, papayas, and plums and prunes.
# 7 Includes apricots and plums and prunes.
# 8 Includes blackberries, blueberries, raspberries, boysenberries, loganberries and apricots.
# 9 Includes prunes and cranberries.  Estimates for cranberries begin in 1989.
# 10 Includes apricots, dates, figs, peaches, pears, and plums and prunes.
# 11 Also includes other processed apples and wine.
# 12 Shelled basis.
# 13 Includes hazelnuts, macadamias, pistachios, Brazil nuts, cashews, and mixed nuts.
#
# Source: USDA, Economic Research Service calculations based on U.S. production data from USDA, National Agricultural Statistics Service and U.S. trade and population data from U.S. Department of Commerce, U.S. Census Bureau.

# %%
# Loadig original Table_A1 -- Only for first time

df_a1 = pd.read_csv("Data_sourse All tables/Table_A1.csv")
df_a1.head()
df_a1.dropna(axis = 'rows', how ='all', inplace = True)
#df_a1.head()
df_a1.set_index('Crop',inplace = True)
df_a1.head(10)
# Out:
#                    1976  1977  1978  1979  1980  1981  1982  1983  1984  1985  \
# Crop
# Apples, all        29.9  31.5  35.9  36.1  39.8  34.6  39.7  41.6  44.3  43.2
#   Fresh            17.1  16.5  17.9  17.1  19.2  16.8  17.5  18.3  18.4  17.3
#   Canning           4.3   4.9   5.5   5.9   5.3   4.4   5.4   5.1   5.0   5.3
#   Freezing          0.8   0.7   1.0   0.7   0.8   0.7   0.8   0.7   0.9   0.8
#   Juice             6.3   7.9   9.6  10.6  13.0  11.5  14.6  15.8  18.4  18.4
#   Dried             1.1   1.0   1.0   1.1   0.8   0.8   0.9   1.2   1.3   1.2
#   Other processed   0.3   0.5   0.8   0.6   0.7   0.4   0.5   0.4   0.4   0.3
# Grapes, all        40.6  37.9  41.3  42.2  47.2  41.2  51.2  44.6  48.2  50.5
#   Fresh             3.5   3.5   3.1   3.4   4.0   4.1   5.7   5.6   6.1   6.8
#   Canning           0.4   0.5   0.5   0.5   0.6   0.4   0.3   0.3   0.3   0.4
#
#                    ...   2009   2010   2011   2012   2013   2014  2015   2016  \
# Crop               ...
# ...

# %%
# set up for fruit_year -- Only for first time

fruit_yr = df_a1.T

fruit_yr.to_csv('dataframe/A1_df.csv')
fruit_yr = pd.read_csv('dataframe/A1_df.csv')
fruit_yr.rename(columns = {'Unnamed: 0':'Year'}, inplace = True)
fruit_yr.set_index('Year',inplace = True)
#total_yr.drop(columns=['Unnamed: 0'], inplace = True)

fruit_yr.to_csv('dataframe/A1_df.csv')
fruit_yr.head()
# Out:
#       Apples, all    Fresh    Canning    Freezing    Juice    Dried  \
# Year
# 1976         29.9     17.1        4.3         0.8      6.3      1.1
# 1977         31.5     16.5        4.9         0.7      7.9      1.0
# 1978         35.9     17.9        5.5         1.0      9.6      1.0
# 1979         36.1     17.1        5.9         0.7     10.6      1.1
# 1980         39.8     19.2        5.3         0.8     13.0      0.8
#
#         Other processed  Grapes, all    Fresh.1    Canning.1  ...     Dried  \
# Year                                                          ...
# 1976                0.3         40.6        3.5          0.4  ...      13.4
# 1977                0.5         37.9        3.5          0.5  ...       9.9
# 1978                0.8         41.3        3.1          0.5  ...       8.6
# 1979                0.6         42.2        3.4          0.5  ...      10.0
# 1980                0.7         47.2        4.0          0.6  ...      11.2
#
# ...

# %%
# fruit_yr dataframe -- loading from csv -- run after second time 
fruit_yr = pd.read_csv('dataframe/A1_df.csv')
fruit_yr.set_index('Year',inplace = True)
fruit_yr.index = fruit_yr.index.map(str)
#print(fruit_yr.columns)
fruit_yr.head(5)  # whole dataframe table set up
# Out:
#       Apples, all    Fresh    Canning    Freezing    Juice    Dried  \
# Year
# 1976         29.9     17.1        4.3         0.8      6.3      1.1
# 1977         31.5     16.5        4.9         0.7      7.9      1.0
# 1978         35.9     17.9        5.5         1.0      9.6      1.0
# 1979         36.1     17.1        5.9         0.7     10.6      1.1
# 1980         39.8     19.2        5.3         0.8     13.0      0.8
#
#         Other processed  Grapes, all    Fresh.1    Canning.1  ...     Dried  \
# Year                                                          ...
# 1976                0.3         40.6        3.5          0.4  ...      13.4
# 1977                0.5         37.9        3.5          0.5  ...       9.9
# 1978                0.8         41.3        3.1          0.5  ...       8.6
# 1979                0.6         42.2        3.4          0.5  ...      10.0
# 1980                0.7         47.2        4.0          0.6  ...      11.2
#
# ...

# %% [markdown]
# ### Total fruits , fresh, canning, freezing, juice, dried Vs year
#
# total_yr ['Total','Fresh', 'Canning', 'Freezing', 'Juice', 'Dried'] subtotal for all the fruits

# %%
# loading from csv -- total_yr -- run after second time

total_yr = pd.read_csv('dataframe/A1_total_yr.csv')  

#total_yr.drop(columns=['Unnamed: 0'], inplace = True)

total_yr.set_index('Year',inplace = True)
total_yr.index = total_yr.index.map(str)

total_yr.head(50)   ## Total all fruits, fresh, canning, freezing, juice Vs year
# Out:
#        Total  Fresh  Canning  Freezing  Juice  Dried
# Year
# 1976  263.60   83.1     23.2       3.3  115.7   13.4
# 1977  276.30   80.2     24.2       3.3  132.4    9.9
# 1978  268.70   83.5     23.9       3.7  119.1    8.6
# 1979  260.00   80.7     24.8       3.1  111.9   10.0
# 1980  278.50   88.3     24.4       3.3  119.1   11.2
# 1981  269.60   83.9     20.8       3.0  124.3    9.6
# 1982  273.90   85.7     21.9       3.3  116.6   12.0
# 1983  286.30   90.5     20.0       3.2  133.2   11.7
# 1984  272.10   88.3     19.6       3.4  117.7   12.7
# 1985  277.00   86.4     20.7       3.5  121.9   12.8
# 1986  282.80   93.8     21.0       4.1  122.7   11.5
# 1987  287.00   96.8     20.8       4.0  126.9   12.1
# 1988  277.20   97.4     20.6       4.0  112.3   14.9
# 1989  279.00   96.3     21.4       4.6  117.5   13.2
# 1990  261.00   92.2     20.9       4.3  107.6   12.1
# 1991  267.20   89.4     19.6       4.1  118.5   12.2
# 1992  270.10   98.7     22.6       4.3  106.3   10.7
# ...

# %%
# original set up -- total_yr -- Only for first time

total_yr = fruit_yr[[' Subtotal, all 11','   Fresh', '   Canning ', '   Freezing', '   Juice ', '   Dried']]
total_yr.columns = ['Total','Fresh', 'Canning', 'Freezing', 'Juice', 'Dried']

 
# total_yr = total_yr.rename(columns = {'Unnamed: 0':'Year'})

# total_yr.drop(columns=['Unnamed: 0.1'], inplace = True)

# total_yr.to_csv('dataframe/A1_total_yr.csv')

# %%
total_yr.plot.line()

plt.title("Per Capita Use of Selected Fruits (Melons excluded)")

plt.ylabel("Pound per capita")
plt.ylim(0, 350)

plt.legend(bbox_to_anchor=(1.01, 0.5), loc = "center left")

# %%
total_fruit_type = total_yr.iloc[: , 1:6 ]
total_fruit_type.plot(kind='bar', stacked='true', width =0.9, figsize=(20,20)) 

plt.legend(bbox_to_anchor=(1.01, 0.5), loc = "center left", prop = {'size':20})

plt.ylabel("Pound per capita", size = 20)
plt.xlabel("Year", size = 20)
ax = plt.gca()
ax.tick_params(axis='both', which='major', labelsize = 18)

plt.title("Per Capita Use of Selected Fruits (Melons excluded)", fontsize = 25)
# Out:
# Text(0.5, 1.0, 'Per Capita Use of Selected Fruits (Melons excluded)')

# %%
fresh_juice = total_yr[['Fresh','Juice']]
fresh_juice.plot()

plt.title("Per Capita Use of Fresh, Juice Selected Fruits (Melons excluded)")

plt.ylabel("Pound per capita")
plt.ylim(0, 200)

plt.legend(bbox_to_anchor=(1.01, 0.5), loc = "center left")

# %%
Can_Dri = total_yr[['Canning','Freezing','Dried']]
Can_Dri.plot()

plt.title("Per Capita Use of Canning, Freezing, Dried Selected Fruits (Melons excluded)")

plt.ylabel("Pound per capita")
plt.ylim(0, 30)

plt.legend(bbox_to_anchor=(1.01, 0.5), loc = "center left")

# %%
total_yr["In refrigerator"] = total_yr.Fresh + total_yr.Freezing + total_yr.Juice
total_yr["Out refrigerator"] = total_yr.Canning + total_yr.Dried

# %%
refrigerator = total_yr[["In refrigerator", "Out refrigerator"]]
refrigerator.plot()

plt.title("Per Capita Use of Selected Fruits")

plt.ylabel("Pound per capita")
#plt.ylim(0, 250)
plt.yscale('log')

plt.legend(bbox_to_anchor=(1.01, 0.5), loc = "center left")
#plt.yscale('log')

# %% [markdown]
# ### Fruit types Vs year
#
# varfruit_yr ['Apples, all', 'Grapes, all', 'Bananas, fresh', 'Oranges, all','Grapefruit, all','Lemons, all','Other citrus, all','Peaches, all','Pears, all', 'Cherries, all',  'Strawberries', 'Pineapples, all', 'Olives, canned', 'Avocados, fresh', 'Other noncitrus, all',  'Melons']  whole use for each fruit

# %%
# original set up  -- Only for first time

varfruit_yr = fruit_yr[['Apples, all', 'Grapes, all', 'Bananas, fresh', 'Oranges, all  ','Grapefruit, all ','Lemons, all ','Other citrus, all 3','Peaches, all  4 5','Pears, all  5', 'Cherries, all',  'Strawberries', 'Pineapples, all', 'Olives, canned ', 'Avocados, fresh ', 'Other noncitrus, all',  '  Melons']]
# varfruit_yr = varfruit_yr.rename(columns = {'Unnamed: 0':'Year'})

varfruit_yr.columns = ['Apples, all', 'Grapes, all', 'Bananas, fresh', 'Oranges, all','Grapefruit, all','Lemons, all','Other citrus, all','Peaches, all','Pears, all', 'Cherries, all',  'Strawberries', 'Pineapples, all', 'Olives, canned', 'Avocados, fresh', 'Other noncitrus, all',  'Melons']

varfruit_yr.head()

varfruit_yr.to_csv('dataframe/A1_varfruit_yr.csv')

# %%
# loading from csv -- varfruit_yr run here -- run after second time

varfruit_yr = pd.read_csv('dataframe/A1_varfruit_yr.csv')

varfruit_yr.set_index('Year',inplace = True)

varfruit_yr.index = varfruit_yr.index.map(str)

#varfruit_yr.to_csv('dataframe/A1_varfruit_yr.csv')

varfruit_yr.head()
# Out:
#       Apples, all  Grapes, all  Bananas, fresh  Oranges, all  Grapefruit, all  \
# Year
# 1976         29.9         40.6            19.3         102.1             19.7
# 1977         31.5         37.9            19.2         110.6             22.1
# 1978         35.9         41.3            20.2          91.8             24.4
# 1979         36.1         42.2            21.0          86.1             21.4
# 1980         39.8         47.2            20.8          95.3             17.5
#
#       Lemons, all  Other citrus, all  Peaches, all  Pears, all  Cherries, all  \
# Year
# 1976          4.3                4.9          11.2         7.1            1.7
# 1977          6.7                4.8          11.5         6.8            1.6
# 1978          7.0                4.3          11.9         6.1            1.4
# 1979          4.6                4.3          12.5         6.9            1.5
# 1980          5.3                5.5          13.1         7.2            1.6
#
# ...

# %%
varfruit_yr.plot()
plt.legend(bbox_to_anchor=(1.01, 0.5), loc = "center left")

plt.ylabel("Pound per capita")
#plt.ylim(0, 250)

plt.title("Per Capita Use of All Fruits")
# Out:
# Text(0.5, 1.0, 'Per Capita Use of All Fruits')

# %%
grapef_melon_yr = pd.read_csv('dataframe/A1_varfruit_yr.csv')
grapef_melon_yr.set_index('Year',inplace = True)
grapef_melon_yr = grapef_melon_yr[['Grapefruit, all','Melons']]

grapef_melon_yr.plot()

# %%
grapef_melon_yr
# Out:
#       Grapefruit, all  Melons
# Year
# 1976             19.7    18.8
# 1977             22.1    19.3
# 1978             24.4    20.1
# 1979             21.4    19.2
# 1980             17.5    18.0
# 1981             19.7    19.4
# 1982             19.4    22.3
# 1983             19.4    19.8
# 1984             12.2    24.1
# 1985             16.6    24.3
# 1986             14.6    24.9
# 1987             17.9    24.7
# 1988             12.8    24.0
# 1989             16.3    26.9
# 1990             19.2    24.8
# 1991             14.4    23.6
# 1992             12.5    25.6
# 1993             14.7    24.9
# 1994             16.2    25.6
# 1995             15.8    26.4
# 1996             15.1    29.3
# 1997             15.2    28.8
# 1998             15.6    28.0
# 1999             14.6    29.7
# 2000             13.2    27.8
# 2001             13.2    28.7
# 2002             11.6    27.9
# 2003             10.1    27.1
# 2004             10.1    25.4
# 2005              6.3    25.6
# ...

# %%
varfruit = varfruit_yr.sum()  # total history use of each fruit
total_fruit = varfruit_yr.sum().sum()  # total history use of all fruits including melons

varfruit_prop = varfruit/total_fruit  # prop of each fruit in the history use

fig1, ax1 = plt.subplots()
labels = ['Apples', 'Grapes', 'Bananas', 'Oranges','Grapefruit','Lemons','Other citrus','Peaches','Pears', 'Cherries',  'Strawberries', 'Pineapples', 'Olives', 'Avocados', 'Other noncitrus',  'Melons']
ax1.pie(varfruit, labels = labels, autopct='%1.1f%%', shadow = False, startangle=90, pctdistance = 0.8, radius = 2.5, labeldistance = 1.1)
# Out:
# ([<matplotlib.patches.Wedge at 0x204eceaaa08>,
# ...
#  [Text(-1.2421511187542145, 2.4534792842365007, 'Apples'),
#   Text(-2.7275698727009305, 0.35051760231724377, 'Grapes'),
#   Text(-2.1988981267253815, -1.6514681432845164, 'Bananas'),
#   Text(0.4865811784863042, -2.706610196674593, 'Oranges'),
#   Text(2.508854547324727, -1.1261211570555103, 'Grapefruit'),
#   Text(2.6857508281785676, -0.5909674178312517, 'Lemons'),
#   Text(2.741384691932314, -0.2175085534850791, 'Other citrus'),
#   Text(2.740284814864693, 0.23095266489472485, 'Peaches'),
#   Text(2.6671163871591346, 0.6700672931483855, 'Pears'),
#   Text(2.603392660951338, 0.8859157143344459, 'Cherries'),
#   Text(2.522554605707507, 1.0950882435785, 'Strawberries'),
#   Text(2.25583644881937, 1.5728006600259337, 'Pineapples'),
#   Text(1.9986395223828302, 1.8888991660671914, 'Olives'),
#   Text(1.9141596948073085, 1.9744600939941006, 'Avocados'),
#   Text(1.6211958967638613, 2.2213112938793653, 'Other noncitrus'),
# ...

# %% [markdown]
# ## Top 5 Fruits Vs Year
#
# topfruit_yr [ 'Oranges_all','Grapes_all','Apples_all','Bananas_fresh','Melons'] top 5 fruits

# %%
varfruit_yr.mean().sort_values(ascending = False)
# Out:
# Oranges, all            79.483721
# Grapes, all             47.951163
# Apples, all             44.441860
# Bananas, fresh          25.253488
# Melons                  24.765116
# Pineapples, all         12.883721
# Grapefruit, all         12.595349
# Other noncitrus, all    10.255814
# Peaches, all             9.325581
# Lemons, all              6.874419
# Other citrus, all        6.155814
# Pears, all               6.041860
# Strawberries             6.013953
# Avocados, fresh          2.965116
# Cherries, all            1.720930
# Olives, canned           1.181395
# dtype: float64

# %%
# top 5 popular fruits over years: orange, grapes, apples, banana, Melons--topfruit_yr original set up -- Only for first time

topfruit_yr = varfruit_yr[['Oranges, all', 'Grapes, all','Apples, all', 'Bananas, fresh', 'Melons']]
topfruit_yr.columns = [ 'Oranges_all','Grapes_all','Apples_all','Bananas_fresh','Melons']
topfruit_yr.index = topfruit_yr.index.map(str)

topfruit_yr['Oranges_prop'] = topfruit_yr.Oranges_all/(total_yr.Total+ topfruit_yr.Melons)
topfruit_yr['Grapes_prop'] = topfruit_yr.Grapes_all/(total_yr.Total+ topfruit_yr.Melons)
topfruit_yr['Apples_prop'] = topfruit_yr.Apples_all/(total_yr.Total+ topfruit_yr.Melons)
topfruit_yr['Bananas_prop'] = topfruit_yr.Bananas_fresh/(total_yr.Total+ topfruit_yr.Melons)
topfruit_yr['Melons_prop'] = topfruit_yr.Melons/(total_yr.Total+ topfruit_yr.Melons)


topfruit_yr.to_csv('dataframe/A1_topfruit_yr.csv')


topfruit_yr.head()
# Out:
# C:\Users\Haoyu Zhang\anaconda3\lib\site-packages\ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   import sys
# C:\Users\Haoyu Zhang\anaconda3\lib\site-packages\ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\Haoyu Zhang\anaconda3\lib\site-packages\ipykernel_launcher.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
# topfruit_yr loading from csv -- run after second time

topfruit_yr = pd.read_csv('dataframe/A1_topfruit_yr.csv')

topfruit_yr.set_index('Year',inplace = True)
topfruit_yr.index = topfruit_yr.index.map(str)

topfruit_yr.head()
# Out:
#       Oranges_all  Grapes_all  Apples_all  Bananas_fresh  Melons  \
# Year
# 1976        102.1        40.6        29.9           19.3    18.8
# 1977        110.6        37.9        31.5           19.2    19.3
# 1978         91.8        41.3        35.9           20.2    20.1
# 1979         86.1        42.2        36.1           21.0    19.2
# 1980         95.3        47.2        39.8           20.8    18.0
#
#       Oranges_prop  Grapes_prop  Apples_prop  Bananas_prop  Melons_prop
# Year
# 1976      0.387329     0.154021     0.113429      0.073217     0.071320
# 1977      0.400290     0.137170     0.114007      0.069490     0.069852
# 1978      0.341645     0.153703     0.133606      0.075177     0.074805
# 1979      0.331154     0.162308     0.138846      0.080769     0.073846
# 1980      0.342190     0.169479     0.142908      0.074686     0.064632

# %%
topfruit_yr.iloc[:, 0:5].plot()

#plt.plot(topfruit_yr.Oranges_all, label = 'Oranges all')
#plt.plot(topfruit_yr.Grapes_all, label = 'Grapes all')
#plt.plot(topfruit_yr.Apples_all, label = 'Apples all')
#plt.plot(topfruit_yr.Bananas_fresh, label = 'Bananas fresh')
#plt.plot(topfruit_yr.Melons, label = 'Melons')

plt.legend(bbox_to_anchor=(1.01, 0.5), loc = "center left")
# plt.xticks(rotation='vertical')


plt.ylabel("Pound per capita")

plt.title("Per Capita Use of Top 5 Fruits")
plt.ylim(0, 120)
# Out:
# (0, 120)

# %%
topfruit_prop = topfruit_yr.iloc[:, 5:10]*100
topfruit_prop.plot()

#plt.plot(topfruit_yr.Oranges_prop, label = 'Oranges prop')
#plt.plot(topfruit_yr.Grapes_prop, label = 'Grapes prop')
#plt.plot(topfruit_yr.Apples_prop, label = 'Apples prop')
#plt.plot(topfruit_yr.Bananas_prop, label = 'Bananas prop')
#plt.plot(topfruit_yr.Melons_prop, label = 'Melons prop')

plt.legend(bbox_to_anchor=(1.01, 0.5), loc = "center left")
#plt.xticks(rotation='vertical')

plt.ylabel("Percentage")
ax = plt.gca()
ax.yaxis.set_major_formatter(mtick.PercentFormatter())

plt.title("Per Capita Use Percentagne of Top 5 Fruits")
plt.ylim(0, 45)
# Out:
# (0, 45)

# %% [markdown]
# ## No.1 Orange Vs Year
# orange_yr [All	Fresh	Juice	Fresh_prop	Juice_prop]  all types orange use, and its prop

# %%
orange_yr = pd.read_csv('dataframe/A1_df.csv')  # only for the first time

orange_yr.set_index('Year',inplace = True)
orange_yr.index = orange_yr.index.map(str)

orange_yr = orange_yr[['Oranges, all  ', '  Fresh.2', '  Juice 2']]
orange_yr.columns = ['All', 'Fresh', 'Juice']

orange_yr['Fresh_prop'] = orange_yr.Fresh/orange_yr.All
orange_yr['Juice_prop'] = orange_yr.Juice/orange_yr.All

orange_yr.head()

orange_yr.to_csv('dataframe/A1_orange.csv')

# %%
orange_yr = pd.read_csv('dataframe/A1_orange.csv')  # run after second time
orange_yr.set_index('Year',inplace = True)
orange_yr.index = orange_yr.index.map(str)
orange_yr.head()
# Out:
#         All  Fresh  Juice  Fresh_prop  Juice_prop
# Year
# 1976  102.1   14.7   87.4    0.143976    0.856024
# 1977  110.6   13.4   97.1    0.121157    0.877939
# 1978   91.8   13.4   78.3    0.145969    0.852941
# 1979   86.1   11.5   74.6    0.133566    0.866434
# 1980   95.3   14.3   81.0    0.150052    0.849948

# %%
orange_yr.iloc[: , 0:3 ].plot()
plt.legend(bbox_to_anchor=(1.01, 0.5), loc = "center left")

plt.ylabel("Pound per capita")

plt.title("Per Capita Use of Oranges")
plt.ylim(0, 115)
# Out:
# (0, 115)

# %%
orange_yr.iloc[: , 1:3 ].plot(kind='bar', stacked='true', width =0.9, figsize=(20,20)) 

plt.legend(bbox_to_anchor=(1.01, 0.5), loc = "center left", prop = {'size':20})

plt.ylabel("Pound per capita", size = 20)
plt.xlabel("Year", size = 20)
ax = plt.gca()
ax.tick_params(axis='both', which='major', labelsize = 18)

plt.title("Per Capita Use of Oranges", fontsize = 25)
# Out:
# Text(0.5, 1.0, 'Per Capita Use of Oranges')

# %%
orange_fresh_juice = orange_yr.iloc[: , 3:5 ]*100
orange_fresh_juice.plot()

plt.legend(bbox_to_anchor=(1.01, 0.5), loc = "center left")

plt.ylabel("Percentage")
ax = plt.gca()
ax.yaxis.set_major_formatter(mtick.PercentFormatter())

plt.title("Percentagne of Fresh, Juice Oranges Use")
plt.ylim(0,100)
# Out:
# (0, 100)

# %%
orange_fresh_juice.plot(kind='barh', stacked='true', rot=0, width = 0.9, figsize=(20,20)) 

plt.legend(bbox_to_anchor=(1.01, 0.5), loc = "center left", prop = {'size':20})

plt.xlabel("Percentage", size = 20)
plt.ylabel("Year", size = 20)
ax = plt.gca()
ax.xaxis.set_major_formatter(mtick.PercentFormatter())
ax.tick_params(axis='both', which='major', labelsize = 18)



#ax.xaxis.set_major_formatter()
plt.xlim(0, 100)
plt.title("Percentagne of Fresh,Juice Oranges Use", fontsize = 25)
# Out:
# Text(0.5, 1.0, 'Percentagne of Fresh,Juice Oranges Use')

# %% [markdown]
# ## No2 Grape Vs Year

# %%
grape_yr = pd.read_csv('dataframe/A1_df.csv')  # only for the first time

grape_yr.set_index('Year',inplace = True)
grape_yr.index = grape_yr.index.map(str)

grape_yr = grape_yr[[ 'Grapes, all', '  Fresh.1','  Canning.1', '  Juice.1', '  Dried (raisins)', '  Wine']]
grape_yr.columns = ['All', 'Fresh', 'Canning', 'Juice', 'Dried', 'Wine']


grape_yr['Fresh_prop'] = grape_yr.Fresh/grape_yr.All
grape_yr['Canning_prop'] = grape_yr.Canning/grape_yr.All
grape_yr['Juice_prop'] = grape_yr.Juice/grape_yr.All
grape_yr['Dried_prop'] = grape_yr.Dried/grape_yr.All
grape_yr['Wine_prop'] = grape_yr.Wine/grape_yr.All

grape_yr.to_csv('dataframe/A1_grape.csv')

# %%
grape_yr = pd.read_csv('dataframe/A1_grape.csv')  # run after second time
grape_yr.set_index('Year',inplace = True)
grape_yr.index = grape_yr.index.map(str)
grape_yr.head()
# Out:
#        All  Fresh  Canning  Juice  Dried  Wine  Fresh_prop  Canning_prop  \
# Year
# 1976  40.6    3.5      0.4    2.4    9.6  24.6    0.086207      0.009852
# 1977  37.9    3.5      0.5    1.9    6.2  25.7    0.092348      0.013193
# 1978  41.3    3.1      0.5    3.4    5.3  29.1    0.075061      0.012107
# 1979  42.2    3.4      0.5    2.5    6.7  28.9    0.080569      0.011848
# 1980  47.2    4.0      0.6    2.7    8.5  31.5    0.084746      0.012712
#
#       Juice_prop  Dried_prop  Wine_prop
# Year
# 1976    0.059113    0.236453   0.605911
# 1977    0.050132    0.163588   0.678100
# 1978    0.082324    0.128329   0.704600
# 1979    0.059242    0.158768   0.684834
# 1980    0.057203    0.180085   0.667373

# %%
grape_yr.iloc[: , 0:6 ].plot()
plt.legend(bbox_to_anchor=(1.01, 0.5), loc = "center left")

plt.ylabel("Pound per capita")

plt.title("Per Capita Use of Grapes")
# Out:
# Text(0.5, 1.0, 'Per Capita Use of Grapes')

# %%
grape_yr.iloc[: , 1:6 ].plot(kind='bar', stacked='true', width =0.9, figsize=(20,20)) 

plt.legend(bbox_to_anchor=(1.01, 0.5), loc = "center left", prop = {'size':20})

plt.ylabel("Pound per capita", size = 20)
plt.xlabel("Year", size = 20)
ax = plt.gca()
ax.tick_params(axis='both', which='major', labelsize = 18)

plt.title("Per Capita Use of Grapes", fontsize = 25)
# Out:
# Text(0.5, 1.0, 'Per Capita Use of Grapes')

# %%
grape_fresh_juice = grape_yr.iloc[: , 6:11 ]*100
grape_fresh_juice.plot()

plt.legend(bbox_to_anchor=(1.01, 0.5), loc = "center left")

plt.ylabel("Percentage")
ax = plt.gca()
ax.yaxis.set_major_formatter(mtick.PercentFormatter())

plt.title("Percentagne of Fresh, Canning, Juice, Dried, Wine,  Grapes Use")
# Out:
# Text(0.5, 1.0, 'Percentagne of Fresh, Canning, Juice, Dried, Wine,  Grapes Use')

# %%
grape_fresh_juice.plot(kind='barh', stacked='true', rot=0, width = 0.9, figsize=(20,20)) 

plt.legend(bbox_to_anchor=(1.01, 0.5), loc = "center left", prop = {'size':20})

plt.xlabel("Percentage", size = 20)
plt.ylabel("Year", size = 20)
ax = plt.gca()
ax.xaxis.set_major_formatter(mtick.PercentFormatter())
ax.tick_params(axis='both', which='major', labelsize = 18)



#ax.xaxis.set_major_formatter()
plt.xlim(0, 100)
plt.title("Percentagne of Fresh, Canning, Juice, Dried, Wine Grapes Use", fontsize = 25)
# Out:
# Text(0.5, 1.0, 'Percentagne of Fresh, Canning, Juice, Dried, Wine Grapes Use')

# %% [markdown]
# ## No. 3.  Apple Vs Year

# %%
apple_yr = pd.read_csv('dataframe/A1_df.csv')  # only for the first time

apple_yr.set_index('Year',inplace = True)
apple_yr.index = apple_yr.index.map(str)

apple_yr = apple_yr[[ 'Apples, all', '  Fresh', '  Canning', '  Freezing', '  Juice','  Dried', '  Other processed']]
apple_yr.columns = ['All', 'Fresh', 'Canning', 'Freezing', 'Juice','Dried', 'Other processed']


for var in apple_yr.columns:
    if var != 'All':
        apple_yr[var+'_prop'] = apple_yr[var]/apple_yr.All

apple_yr.to_csv('dataframe/A1_apple.csv')

# %%
apple_yr = pd.read_csv('dataframe/A1_apple.csv')  # run after second time
apple_yr.set_index('Year',inplace = True)
apple_yr.index = apple_yr.index.map(str)
apple_yr.head()
# Out:
#        All  Fresh  Canning  Freezing  Juice  Dried  Other processed  \
# Year
# 1976  29.9   17.1      4.3       0.8    6.3    1.1              0.3
# 1977  31.5   16.5      4.9       0.7    7.9    1.0              0.5
# 1978  35.9   17.9      5.5       1.0    9.6    1.0              0.8
# 1979  36.1   17.1      5.9       0.7   10.6    1.1              0.6
# 1980  39.8   19.2      5.3       0.8   13.0    0.8              0.7
#
#       Fresh_prop  Canning_prop  Freezing_prop  Juice_prop  Dried_prop  \
# Year
# 1976    0.571906      0.143813       0.026756    0.210702    0.036789
# 1977    0.523810      0.155556       0.022222    0.250794    0.031746
# 1978    0.498607      0.153203       0.027855    0.267409    0.027855
# 1979    0.473684      0.163435       0.019391    0.293629    0.030471
# 1980    0.482412      0.133166       0.020101    0.326633    0.020101
#
#       Other processed_prop
# Year
# 1976              0.010033
# 1977              0.015873
# 1978              0.022284
# ...

# %%
apple_yr.iloc[: , 0:7 ].plot()
plt.legend(bbox_to_anchor=(1.01, 0.5), loc = "center left")

plt.ylabel("Pound per capita")

plt.title("Per Capita Use of Apples")
# Out:
# Text(0.5, 1.0, 'Per Capita Use of Apples')

# %%
apple_yr.iloc[: , 1:7 ].plot(kind='bar', stacked='true', width =0.9, figsize=(20,20)) 

plt.legend(bbox_to_anchor=(1.01, 0.5), loc = "center left", prop = {'size':20})

plt.ylabel("Pound per capita", size = 20)
plt.xlabel("Year", size = 20)
ax = plt.gca()
ax.tick_params(axis='both', which='major', labelsize = 20)

plt.title("Per Capita Use of Apples", fontsize = 25)
# Out:
# Text(0.5, 1.0, 'Per Capita Use of Apples')

# %%
apple_fresh_juice = apple_yr.iloc[: , 7: ]*100
apple_fresh_juice.plot(kind='barh', stacked='true', rot=0, width = 0.9, figsize=(20,20)) 

plt.legend(bbox_to_anchor=(1.01, 0.5), loc = "center left", prop = {'size':20})

plt.xlabel("Percentage", size = 20)
plt.ylabel("Year", size = 20)
ax = plt.gca()
ax.xaxis.set_major_formatter(mtick.PercentFormatter())
ax.tick_params(axis='both', which='major', labelsize = 18)



#ax.xaxis.set_major_formatter()
plt.xlim(0, 100)
plt.title("Percentagne of Fresh, Canning, Freezing, Juice, Dried and Other processed Apples Use", fontsize = 25)
# Out:
# Text(0.5, 1.0, 'Percentagne of Fresh, Canning, Freezing, Juice, Dried and Other processed Apples Use')

# %%
apple_fresh_juice.plot()

plt.legend(bbox_to_anchor=(1.01, 0.5), loc = "center left")

plt.ylabel("Percentage")
ax = plt.gca()
ax.yaxis.set_major_formatter(mtick.PercentFormatter())

plt.title("Percentagne of Fresh, Canning, Freezing, Juice, Dried and Other processed Apples Use")
# Out:
# Text(0.5, 1.0, 'Percentagne of Fresh, Canning, Freezing, Juice, Dried and Other processed Apples Use')

# %% [markdown]
# ## No. 6. Pineapples

# %%
pineapple_yr = pd.read_csv('dataframe/A1_df.csv')
pineapple_yr.columns
# Out:
# Index(['Year', 'Apples, all', '  Fresh', '  Canning', '  Freezing', '  Juice',
#        '  Dried', '  Other processed', 'Grapes, all', '  Fresh.1',
#        '  Canning.1', '  Juice.1', '  Dried (raisins)', '  Wine',
#        'Bananas, fresh', 'Oranges, all  ', '  Fresh.2', '  Juice 2',
#        'Grapefruit, all ', '  Fresh.3', '  Juice.2', 'Lemons, all ',
#        '  Fresh.4', '  Juice.3', 'Other citrus, all 3', '  Fresh.5',
#        '  Juice.4', 'Peaches, all  4 5', '  Fresh.6', '  Canning.2',
#        '  Freezing.1', 'Pears, all  5', '  Fresh.7', '  Canning.3',
#        'Cherries, all', '  Fresh.8', '  Canning.4', '  Freezing.2',
#        'Strawberries', '  Fresh.9', '  Freezing.3', 'Pineapples, all',
#        '  Fresh.10', '  Canning.5', '  Juice.5', 'Olives, canned ',
#        'Avocados, fresh ', 'Other noncitrus, all', '  Fresh 6', '  Canning 7',
#        '  Freezing 8', '  Juice 9', '  Dried 10', ' Subtotal, all 11',
# ...

# %%
pineapple_yr = pd.read_csv('dataframe/A1_df.csv')  # only for the first time

pineapple_yr.set_index('Year',inplace = True)
pineapple_yr.index = pineapple_yr.index.map(str)

pineapple_yr = pineapple_yr[[  'Pineapples, all','  Fresh.10', '  Canning.5', '  Juice.5']]
pineapple_yr.columns = ['All', 'Fresh', 'Canning', 'Juice']


for var in pineapple_yr.columns:
    if var != 'All':
        pineapple_yr[var+'_prop'] = pineapple_yr[var]/pineapple_yr.All

pineapple_yr.to_csv('dataframe/A1_pineapple.csv')

# %%
pineapple_yr = pd.read_csv('dataframe/A1_pineapple.csv')  # run after second time
pineapple_yr.set_index('Year',inplace = True)
pineapple_yr.index = pineapple_yr.index.map(str)
pineapple_yr.head()
# Out:
#        All  Fresh  Canning  Juice  Fresh_prop  Canning_prop  Juice_prop
# Year
# 1976  10.3    1.1      6.0    3.1    0.106796      0.582524    0.300971
# 1977  10.9    1.4      6.0    3.6    0.128440      0.550459    0.330275
# 1978  10.8    1.4      5.7    3.7    0.129630      0.527778    0.342593
# 1979  12.0    1.5      6.3    4.3    0.125000      0.525000    0.358333
# 1980  12.1    1.5      6.0    4.6    0.123967      0.495868    0.380165

# %%
pineapple_yr.iloc[: , 1:4 ].plot(kind='bar', stacked='true', width =0.9, figsize=(20,20)) 

plt.legend(bbox_to_anchor=(1.01, 0.5), loc = "center left", prop = {'size':20})

plt.ylabel("Pound per capita", size = 20)
plt.xlabel("Year", size = 20)
ax = plt.gca()
ax.tick_params(axis='both', which='major', labelsize = 20)

plt.title("Per Capita Use of Pineapples", fontsize = 25)
# Out:
# Text(0.5, 1.0, 'Per Capita Use of Pineapples')

# %%
pineapple_fresh_juice = pineapple_yr.iloc[: , 4: ]*100
pineapple_fresh_juice.plot(kind='barh', stacked='true', rot=0, width = 0.9, figsize=(20,20)) 

plt.legend(bbox_to_anchor=(1.01, 0.5), loc = "center left", prop = {'size':20})

plt.xlabel("Percentage", size = 20)
plt.ylabel("Year", size = 20)
ax = plt.gca()
ax.xaxis.set_major_formatter(mtick.PercentFormatter())
ax.tick_params(axis='both', which='major', labelsize = 18)


#ax.xaxis.set_major_formatter()
plt.xlim(0, 100)
plt.title("Percentagne of Fresh, Juice Pineapples Use", fontsize = 25)
# Out:
# Text(0.5, 1.0, 'Percentagne of Fresh, Juice Pineapples Use')

# %%
pineapple_yr.iloc[: , 0:4 ].plot()
plt.legend(bbox_to_anchor=(1.01, 0.5), loc = "center left")

plt.ylabel("Pound per capita")

plt.title("Per Capita Use of Pineapples")
plt.ylim(0,25)
# Out:
# (0, 25)

# %%
pineapple_fresh_juice = pineapple_yr.iloc[: , 4: ]*100
pineapple_fresh_juice.plot()

plt.legend(bbox_to_anchor=(1.01, 0.5), loc = "center left")

plt.ylabel("Percentage")
ax = plt.gca()
ax.yaxis.set_major_formatter(mtick.PercentFormatter())
plt.ylim(0,100)

plt.title("Percentagne of Fresh, Juice Pineapples Use")
# Out:
# Text(0.5, 1.0, 'Percentagne of Fresh, Juice Pineapples Use')

# %% [markdown]
# ## Table E-1--U.S. per capita use of melons, 1970 to date
#
# ![image.png](attachment:image.png)

# %%
df_e1 = pd.read_csv("Data_sourse All tables/Table_E1.csv")  # first time to run 

#df_a1.head()
#df_a1.set_index('Crop',inplace = True)

df_e1.dropna(axis = 'columns', how ='all', inplace = True)

column = ['Year', 'Watermelon', 'Cantaloupe', 'Honeydew', 'Others', 'Total melons']
df_e1 = df_e1[ 4: ]
df_e1.columns = column

df_e1.set_index('Year',inplace = True)

for var in df_e1.columns:
    df_e1[var] = df_e1[var].map(lambda x : float(x))

for var in df_e1.columns:
    if var != 'Total melons':
        df_e1[var+'_prop'] = df_e1[var]/df_e1['Total melons']

df_e1.to_csv('dataframe/E1_df.csv')

# %%
df_e1 = pd.read_csv('dataframe/E1_df.csv')  # after the second time
df_e1.set_index('Year',inplace = True)
#fruit_yr.index = fruit_yr.index.map(str)
#print(fruit_yr.columns)

df_e1.head(5)
# Out:
#       Watermelon  Cantaloupe  Honeydew  Others  Total melons  Watermelon_prop  \
# Year
# 1970       13.50        7.20      0.90     0.0         21.60         0.625000
# 1971       13.04        6.64      0.93     0.0         20.61         0.632703
# 1972       12.31        6.77      1.04     0.0         20.12         0.611829
# 1973       12.74        5.88      1.11     0.0         19.73         0.645717
# 1974       11.32        5.14      1.01     0.0         17.47         0.647968
#
#       Cantaloupe_prop  Honeydew_prop  Others_prop
# Year
# 1970         0.333333       0.041667          0.0
# 1971         0.322174       0.045124          0.0
# 1972         0.336481       0.051690          0.0
# 1973         0.298023       0.056260          0.0
# 1974         0.294219       0.057813          0.0

# %%
melon_yr = df_e1.iloc[: , 0:4 ]

melon_yr.plot(kind='bar', stacked='true', width =0.9, figsize=(20,20)) 

plt.legend(bbox_to_anchor=(1.01, 0.5), loc = "center left", prop = {'size':20})

plt.ylabel("Pound per capita", size = 20)
plt.xlabel("Year", size = 20)
ax = plt.gca()
ax.tick_params(axis='both', which='major', labelsize = 20)

plt.title("Per Capita Use of Melons", fontsize = 25)
# Out:
# Text(0.5, 1.0, 'Per Capita Use of Melons')

# %%
melon_type_ratio = df_e1.iloc[: , 5: ]*100
melon_type_ratio.plot(kind='barh', stacked='true', rot=0, width = 0.9, figsize=(20,20)) 

plt.legend(bbox_to_anchor=(1.01, 0.5), loc = "center left", prop = {'size':20})

plt.xlabel("Percentage", size = 20)
plt.ylabel("Year", size = 20)
ax = plt.gca()
ax.xaxis.set_major_formatter(mtick.PercentFormatter())
ax.tick_params(axis='both', which='major', labelsize = 18)


#ax.xaxis.set_major_formatter()
plt.xlim(0, 100)
plt.title("Percentagne of Melons Use", fontsize = 25)
# Out:
# Text(0.5, 1.0, 'Percentagne of Melons Use')
