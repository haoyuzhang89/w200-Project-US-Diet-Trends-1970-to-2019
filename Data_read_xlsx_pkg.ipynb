# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
import copy

# %matplotlib inline

xls = pd.ExcelFile('General.xlsx')
df1 = pd.read_excel(xls, 'Table1a-PerCapitaAvail. (70-82)')
#df2 = pd.read_excel(xls, 'Sheet2')
print(type(df1))

print(df1.shape)
df1.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# (81, 14)
#   Table 1a--U.S. per capita availability of selected, commercially produced, fresh and processing vegetables and dry pulse crops.1   \
# 0                                               Crop
# 1                                                NaN
# 2                                    Asparagus, all
# 3                                   Asparagus, fresh
# 4                                 Asparagus, canning
#
#                                           Unnamed: 1 Unnamed: 2 Unnamed: 3  \
# 0                                               1970       1971       1972
# 1  ——————————————————————————  Pounds per person ...        NaN        NaN
# 2                                            1.33146    1.27763    1.26558
# 3                                           0.441932   0.378627   0.403152
# 4                                             0.5949   0.629031   0.612521
#
# ...

# %%
df1_tran = df1.T

# %%
df1_tran.head()
# Out:
#                                                       0   \
# Table 1a--U.S. per capita availability of selec...  Crop
# Unnamed: 1                                          1970
# Unnamed: 2                                          1971
# Unnamed: 3                                          1972
# Unnamed: 4                                          1973
#
#                                                                                                    1   \
# Table 1a--U.S. per capita availability of selec...                                                NaN
# Unnamed: 1                                          ——————————————————————————  Pounds per person ...
# Unnamed: 2                                                                                        NaN
# Unnamed: 3                                                                                        NaN
# Unnamed: 4                                                                                        NaN
#
# ...

# %%
df1_tran.columns
# Out:
# RangeIndex(start=0, stop=81, step=1)

# %%
df1_tran.set_index(df1_tran[0], inplace = True)

# %%
df1_tran.columns = df1_tran.iloc[0]
df1_tran.head()
# Out:
# Crop                                                NaN  Asparagus, all   \
# 0
# Crop                                                NaN  Asparagus, all
# 1970  ——————————————————————————  Pounds per person ...          1.33146
# 1971                                                NaN          1.27763
# 1972                                                NaN          1.26558
# 1973                                                NaN          1.29273
#
# Crop  Asparagus, fresh  Asparagus, canning  Asparagus, freezing   \
# 0
# Crop  Asparagus, fresh  Asparagus, canning  Asparagus, freezing
# 1970          0.441932              0.5949              0.294629
# 1971          0.378627            0.629031              0.269971
# 1972          0.403152            0.612521              0.249909
# 1973          0.400342            0.644938              0.247446
#
# Crop  Snap /Green beans, all  Snap /Green beans,fresh   \
# 0
# Crop  Snap /Green beans, all  Snap /Green beans,fresh
# ...

# %%
df1_tran.columns
# Out:
# Index(['Asparagus, all ', 'Asparagus, fresh', 'Asparagus, canning',
#        'Asparagus, freezing ', 'Snap /Green beans, all',
#        'Snap /Green beans,fresh ', 'Snap /Green beans, canning',
#        'Snap /Green beans, freezing  ', 'Broccoli, all ', 'Broccoli, fresh ',
#        'Broccoli, freezing ', 'Cabbage, all ', 'Cabbage, fresh ',
#        'Cabbage, canning ', 'Carrots, all ', 'Carrots, fresh ',
#        'Carrots, canning ', 'Carrots, freezing ', 'Cauliflower, all ',
#        'Cauliflower, fresh ', 'Cauliflower, freezing ', 'Celery',
#        'Sweet corn, all 1', 'Sweet corn, fresh ', 'Sweet corn, canning ',
#        'Sweet corn, freezing ', 'Cucumbers, all ', 'Cucumbers, fresh ',
#        'Cucumbers, pickling ', 'Melons2', 'Watermelon', 'Cantaloupe',
#        'Honeydew', 'Melons, other ', 'Lettuce, all ', 'Lettuce, head ',
#        'Lettuce, leaf /romaine  ', 'Onions, all ', 'Onions, fresh ',
#        'Onions, dehydrating ', 'Green peas, all 3', 'Green peas, canning ',
# ...

# %%
df1_tran.drop(columns = np.nan, inplace = True)

df1_tran.head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-52-b403a7c9ab24> in <module>
# ----> 1 df1_tran.drop(columns = np.nan, inplace = True)
#       2
#       3 df1_tran.head()
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3995             level=level,
#    3996             inplace=inplace,
# -> 3997             errors=errors,
#    3998         )
#    3999
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3934         for axis, labels in axes.items():
#    3935             if labels is not None:
# -> 3936                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    3937
#    3938         if inplace:
#
# ...
